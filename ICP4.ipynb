# %% [markdown]
# <a href="https://colab.research.google.com/github/Kavyakandhakatla/BDA_ICP1/blob/main/ICP4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = {
    'ID': np.arange(1, 1000001),
    'Value': np.random.rand(1000000),
    'Category': np.random.choice(['A', 'B', 'C', 'D'], size=1000000)
}


df = pd.DataFrame(data)

# %%
print(df.head(10))
# Out:
#    ID     Value Category
# 0   1  0.221317        B
# 1   2  0.100814        B
# 2   3  0.865962        D
# 3   4  0.783553        C
# 4   5  0.043337        C
# 5   6  0.057383        A
# 6   7  0.400355        D
# 7   8  0.236281        A
# 8   9  0.231501        A
# 9  10  0.406549        A

# %%
print(df['Value'].head(10))
# Out:
# 0    0.221317
# 1    0.100814
# 2    0.865962
# 3    0.783553
# 4    0.043337
# 5    0.057383
# 6    0.400355
# 7    0.236281
# 8    0.231501
# 9    0.406549
# Name: Value, dtype: float64

# %%
df.columns = ['ID number', 'Random value', 'Choice']

print(df.head(5))
# Out:
#    ID number  Random value Choice
# 0          1      0.221317      B
# 1          2      0.100814      B
# 2          3      0.865962      D
# 3          4      0.783553      C
# 4          5      0.043337      C

# %%
pd.set_option('display.max_rows', None)

student_data = pd.DataFrame({
    'school_code': ['s001', 's002', 's003', 's001', 's002', 's004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco', 'Gino Mcneill', 'Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'Date_Of_Birth': ['15/05/2002', '17/05/2002', '16/02/1999', '25/09/1998', '11/05/2002', '15/09/1997'],
    'age': [12, 12, 13, 13, 14, 12],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']
}, index=['S1', 'S2', 'S3', 'S4', 'S5', 'S6'])

print("Original DataFrame:")
print(student_data)

print("\nSplit the said data on school_code, class wise:")
result = student_data.groupby(['school_code', 'class'])

for name, group in result:
    print("\nGroup:")
    print(name)
    print(group)
# Out:
# Original DataFrame:
#    school_code class            name Date_Of_Birth  age  height  weight  \
# S1        s001     V  Alberto Franco    15/05/2002   12     173      35
# S2        s002     V    Gino Mcneill    17/05/2002   12     192      32
# S3        s003    VI     Ryan Parkes    16/02/1999   13     186      33
# S4        s001    VI    Eesha Hinton    25/09/1998   13     167      30
# S5        s002     V    Gino Mcneill    11/05/2002   14     151      31
# S6        s004    VI    David Parkes    15/09/1997   12     159      32
#
#     address
# S1  street1
# S2  street2
# S3  street3
# S4  street1
# S5  street2
# S6  street4
#
# Split the said data on school_code, class wise:
#
# Group:
# ('s001', 'V')
#    school_code class            name Date_Of_Birth  age  height  weight  \
# S1        s001     V  Alberto Franco    15/05/2002   12     173      35
#
#     address
# S1  street1
#
# Group:
# ('s001', 'VI')
# ...

# %%
from google.colab import files

uploaded = files.upload()

df = pd.read_csv('data.csv')

print(df.head(4))
# Out:
#      <input type="file" id="files-88d8994c-d05d-4397-85a4-1a25c012a49b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-88d8994c-d05d-4397-85a4-1a25c012a49b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
df[df.isnull().any(axis=1)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 17         45     90       112       NaN
# 27         60    103       132       NaN
# 91         45    107       137       NaN
# 118        60    105       125       NaN
# 141        60     97       127       NaN

# %%
df.fillna(df.mean(),inplace=True)
print("replaced null values with mean")
# Out:
# replaced null values with mean

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Duration, Pulse, Maxpulse, Calories]
# Index: []

# %%
print("Min of pulse:", df['Pulse'].min())
print("Max of pulse:", df['Pulse'].max())
print("Count of pulse:", df['Pulse'].count())
print("Mean of pulse:", df['Pulse'].mean())

print("Min of Duration:", df['Duration'].min())
print("Max of Duration:", df['Duration'].max())
print("Count of Duration:", df['Duration'].count())
print("Mean of Duration:", df['Duration'].mean())
# Out:
# Min of pulse: 80
# Max of pulse: 159
# Count of pulse: 169
# Mean of pulse: 107.46153846153847
# Min of Duration: 15
# Max of Duration: 300
# Count of Duration: 169
# Mean of Duration: 63.84615384615385

# %%
filter = df[(df['Calories'] >= 500) & (df['Calories'] <= 1000)]
print(filter)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 51         80    123       146     643.1
# 62        160    109       135     853.0
# 65        180     90       130     800.4
# 66        150    105       135     873.4
# 67        150    107       130     816.0
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 78        120    100       130     500.4
# 83        120    100       130     500.0
# 90        180    101       127     600.1
# 99         90     93       124     604.1
# 101        90     90       110     500.0
# 102        90     90       100     500.0
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
filter = df[(df['Calories'] > 500) & (df['Pulse'] < 100)]
print(filter)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 65        180     90       130     800.4
# 70        150     97       129    1115.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
df_modified = df.drop(columns=['Maxpulse'])
print(df_modified.columns)
print(df.columns)
# Out:
# Index(['Duration', 'Pulse', 'Calories'], dtype='object')
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
print(df.columns)
df.drop(columns=['Maxpulse'], inplace=True)
print(df.columns)
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')
# Index(['Duration', 'Pulse', 'Calories'], dtype='object')

# %%
df['Calories'] = df['Calories'].astype(int)
print(df.Calories.dtype)
# Out:
# int64

# %%
import matplotlib.pyplot as plt

df.plot.scatter(x='Duration', y='Calories', title='Duration versus Calories')

plt.show()

# %% [markdown]
# https://drive.google.com/file/d/1a2kbJLr1w6S-TiN_YXC9OiSPmMT5aL_f/view?usp=drive_link
